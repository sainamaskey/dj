# %%
#CRUD
# Create
# Read
# Update
# Delete

# %%
#? python -m venv venv_foldername - version conflicts could
# pip install django djangorestframework
# Django rest framework for api
# Django - web framework
#? django-admin startproject myproject
#? inside myporject
#? python manage.py startapp myapp
#? python manage.py runserver

# %% [markdown]
# # setting.py -> tells to run app
# INSTALLED_APPS = [
#     'django.contrib.admin',
#     'django.contrib.auth',
#     'django.contrib.contenttypes',
#     'django.contrib.sessions',
#     'django.contrib.messages',
#     'django.contrib.staticfiles',
#     'myapp',
#     'rest_framework',
# ]

# %%
#models added

#? python manage.py makemigrations
#? python manage.py migrate 
# -runserver
# url ma /admin

# python manage.py createsuperuser

#create-superuser
#django admin panel ma access

#admin.py
# manage data from admin UI

# %%
# Serializer
# convert model to json - wout this api cant send and receive data

# %%
# Views - all the logic

# %%
# my projects and my app -> url.py
# connects the api end points

# %%
#PUT le all update
#PATCH le halka update
