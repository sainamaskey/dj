# %% [markdown]
# Database
# Database rules
# primary key -> unique
# not null -> not empty
# unique -> eg email
# default
# max length
# foreign key -> 1 table link to arko table

# %%
# # database relationships 
# one to one
# one to many
# one to one
# many to many
# Out:
#   Cell In[2], line 2
#     one to one
#         ^
# SyntaxError: invalid syntax
