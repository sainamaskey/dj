# %%
print ("hello")
#Task-2  concepts covered : [Lists if–else loops calculations user input]
#Create a Python program that:
#Allows the user to enter 5 shopping items.

#For each item, ask for:
#Item name
#Price
#Quantity
#Store the data in lists.

#Display the complete shopping list with price and quantity.
#Calculate the total cost for each item.
#Calculate the final bill amount.

#Ask the user to search for an item and check using if–else whether the item exists in the list.
# Out:
# hello

# %%
item = []
price_list = []
quantity_list = []
total_cost = 0
item_price = []

for i in range (2):
    items = input ("enter the shopping list item " +str(i+1))
    item.append(items)


print ("shoppinglist is ", item)

for i in item:
        prices  = float(input ("enter price of "  + i )) 
        price_list.append(prices)
        quantity = int(input ("enter quantity of " + i))
        quantity_list.append(quantity)
        item_price.append(prices * quantity)

for a in item:
#for i in range(len(item)):
      print ("item ->", item[a], "price ", price_list[a], "-> quantity is ", quantity_list[a])
      total_cost += price_list[a] * quantity_list[a]

print ("\n")
for i in range(len(item)):
      print ("the total cost of ", item[i], " is ", item_price[i])

print ("\ntotal bill amount is ", total_cost)

search_item = input ("enter the item you want to search ")
if search_item in item:
    print ("item ", search_item, " is present")
else:    print ("item "+search_item+" is not present")
# Out:
# shoppinglist is  ['fan', 'can']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 23
#      19         item_price.append(prices * quantity)
#      21 for a in item:
#      22 #for i in range(len(item)):
# ---> 23       print ("item ->", item[a], "price ", price_list[a], "-> quantity is ", quantity_list[a])
#      24       total_cost += price_list[a] * quantity_list[a]
#      26 print ("\n")
#
# TypeError: list indices must be integers or slices, not str
