# %%
p = int(input("enter p "))
t = float(input("enter t"))
r = float(input ("enter r"))

i = p*t*r/100
print ("its", i)
# Out:
# its 0.6

# %%
name = input ("enter your name ")
address = input ("enter your address ")
info  = "hello "+name+" your address is "+address
print (info)
# Out:
# hello saina your address is pokhara

# %%
age = int(input("enter your age "))
if age >= 18:
    print ("you are eligible to vote")
elif age < 18 and age > 0:
    print ("you are not eligible to vote")
else:
    print ("you are not eligible to vote")
# Out:
# you are eligible to vote

# %%
for i in range (2 ):
    print (i, "hello world")
# Out:
# 0 hello world
# 1 hello world

# %%
n = int(input("enter n "))
for i in range (2,22):
    print (i, "hello world")    
    # goes till 21
# Out:
# 2 hello world
# 3 hello world
# 4 hello world
# 5 hello world
# 6 hello world
# 7 hello world
# 8 hello world
# 9 hello world
# 10 hello world
# 11 hello world
# 12 hello world
# 13 hello world
# 14 hello world
# 15 hello world
# 16 hello world
# 17 hello world
# 18 hello world
# 19 hello world
# 20 hello world
# 21 hello world

# %%
a = "hellow woek"
for i in a :
    print (i, end="")
# Out:
# hellow woek

# %%
a = "pythondffffffffffffffffff"
print (a[2])
print (a[0:2])
print (a[0:7:3])
# Out:
# t
# py
# phd

# %%
a = "python"
l=len(a)

i=0
while (i<l):
    print (a[i], end="  ")
    i = i+1
# Out:
# p  y  t  h  o  n

# %%
inFo = ["Ram", "kai", "sam", "dyam", "sauni"]
name = "ram"

if name in info:
    print ("name is present")
    print (info.count(name))
else:    print ("name is not present")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 inFo = ["Ram", "kai", "sam", "dyam", "sauni"]
#       2 name = "ram"
# ----> 4 if name in info:
#       5     print ("name is present")
#       6     print (info.count(name))
#
# NameError: name 'info' is not defined

# %%
#split 
info  = " name shyam hari sita gita"
c = info.split()
print (c)
# Out:
# ['name', 'shyam', 'hari', 'sita', 'gita']

# %%
for i in range (5, 2, -1):
    print (i)

    # 2 is ending value
# Out:
# 5
# 4
# 3

# %%
a = "apple"
print (a[4:3:-1])
# 4 is starting value and 3 is ending value and -1 is step value
print (a[::-1])
# Out:
# e
# elppa

# %%
#string formatting 
name = "geet"
roll =3
info = f"{name}{roll}"
print (info)
# Out:
# geet3

# %%
info  = "ram shyam ".lower()
print (info)
print (info.upper())
# Out:
# ram shyam
# RAM SHYAM

# %%
# list tuple dict set
list = [1,2,3,4,5]
print (list[1])
print (list[0:5:2])
# Out:
# 2
# [1, 3, 5]

# %%
# a = list()
list.append(1)
list.append(2)
print (list)
# Out:
# [1, 2, 3, 4, 5, 1, 1, 2, 1, 2, 1, 2]

# %%
ja = ["jh", "kh"]
b = [2,34]
a.extend(b)
print (a)
# Out:
# ['jh', 'kh', 2, 34]
