# %%
authentication and authorization

# %%
authentication - who are you?
-process od verifying identity
-login steps

# %%
authorization - authenticated user le kk access garna paune
can decide what an authenticated user is allowed to access

# %%
middleware - a layer/guard between request and response

user calls an api
    1. middleware
        #logs request
        #checks headers

    2. authentication
        #verify user(token/password)

    3. authorization
    4. VIEW EXECUTES
    5. RESPONSE PASSES BACK THROUGH MIDDLEWARE
